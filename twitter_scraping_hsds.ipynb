# %%
# !python --version #az snscrape-hez kellett legalább 3.8as python
# Out:
# Python 3.9.7

# %%
# %pip install snscrape
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\Users\Murgi\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
temp = []
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:TheOfficialSBI -filter:replies since:2012-01-01 until:2023-04-04').get_items()):
    temp.append([tweet.url, tweet.user, tweet.id, tweet.date, tweet.content, tweet.likeCount, tweet.replyCount, tweet.retweetCount, tweet.quoteCount, tweet.media, tweet.lang, tweet.retweetedTweet, tweet.quotedTweet, tweet.mentionedUsers])
    #if i == 300:
    #    break
    if i%1000 == 0:
        print(tweet.date)
    
fix_tweet_df = pd.DataFrame(temp, columns=["Tweet url", "User", "Tweet id", "Tweet Date", "Tweet Content", "Amount of Likes", "Amount of Replies", "Amount of Retweets", "Amount of Quotes", "Media", "Language", "Is a Retweet", "Is a Quoted Tweet", "Mentioned Users"])
# Out:
# Error retrieving https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&send_error_codes=true&simple_quoted_tweets=true&q=from%3ATheOfficialSBI+-filter%3Areplies+since%3A2012-01-01+until%3A2022-10-04&tweet_search_mode=live&count=100&query_source=spelling_expansion_revert_click&pc=1&spelling_corrections=1&ext=mediaStats%2ChighlightedLabel: non-200 status code
# ...

# %%
len(list(banks['Bank Twitter accountja']))
# Out:
# 105

# %% [markdown]
# **------------------------------------------------------------------------------------------------------**
#
# Here I scrape the tweets of the original banks from the end of the year 2022.

# %%
temp = []
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:TheOfficialSBI -filter:replies since:2022-10-04 until:2023-01-01').get_items()):
    temp.append([tweet.url, tweet.user, tweet.id, tweet.date, tweet.content, tweet.likeCount, tweet.replyCount, tweet.retweetCount, tweet.quoteCount, tweet.media, tweet.lang, tweet.retweetedTweet, tweet.quotedTweet, tweet.mentionedUsers])
    #if i == 300:
    #    break
    if i%1000 == 0:
        print(tweet.date)
    
old_bank_tweets_2022 = pd.DataFrame(temp, columns=["Tweet url", "User", "Tweet id", "Tweet Date", "Tweet Content", "Amount of Likes", "Amount of Replies", "Amount of Retweets", "Amount of Quotes", "Media", "Language", "Is a Retweet", "Is a Quoted Tweet", "Mentioned Users"])
# Out:
# 2022-12-31 18:38:49+00:00

# %%
old_bank_tweets_2022.shape
# Out:
# (242, 14)

# %%
for bank in list(banks['Bank Twitter accountja'])[1:]:
    bank = bank.replace('@', "")
    temp = []
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:'+bank +' -filter:replies since:2022-10-04 until:2023-01-01').get_items()):
        temp.append([tweet.url, tweet.user, tweet.id, tweet.date, tweet.content, tweet.likeCount, tweet.replyCount, tweet.retweetCount, tweet.quoteCount, tweet.media, tweet.lang, tweet.retweetedTweet, tweet.quotedTweet, tweet.mentionedUsers])
    
    temp_df = pd.DataFrame(temp, columns=["Tweet url", "User", "Tweet id", "Tweet Date", "Tweet Content", "Amount of Likes", "Amount of Replies", "Amount of Retweets", "Amount of Quotes", "Media", "Language", "Is a Retweet", "Is a Quoted Tweet", "Mentioned Users"])
    old_bank_tweets_2022 = pd.concat([old_bank_tweets_2022, temp_df], ignore_index=True)
    print(old_bank_tweets_2022.shape)
# Out:
# (806, 14)
# (845, 14)
# (948, 14)
# (978, 14)
# (991, 14)
# (1016, 14)
# (1064, 14)
# (1082, 14)
# (1138, 14)
# (1355, 14)
# (1370, 14)
# (1462, 14)
# (1534, 14)
# (1766, 14)
# (1818, 14)
# (2115, 14)
# (2115, 14)
# (2250, 14)
# (2285, 14)
# (2844, 14)
# (2914, 14)
# (2917, 14)
# (3085, 14)
# (3102, 14)
# (3156, 14)
# (3167, 14)
# (3197, 14)
# (3421, 14)
# (3506, 14)
# (3564, 14)
# (3808, 14)
# (3836, 14)
# (4002, 14)
# (4219, 14)
# (4219, 14)
# (4398, 14)
# (4463, 14)
# (4633, 14)
# (4827, 14)
# (4865, 14)
# (4868, 14)
# (4884, 14)
# (4966, 14)
# (5101, 14)
# (5138, 14)
# (5478, 14)
# (5581, 14)
# (5751, 14)
# (5804, 14)
# (5819, 14)
# (6005, 14)
# (6058, 14)
# (6107, 14)
# (6184, 14)
# (6392, 14)
# (6447, 14)
# (6600, 14)
# (6713, 14)
# (6733, 14)
# (6819, 14)
# (6834, 14)
# (6933, 14)
# (6961, 14)
# (7084, 14)
# (7162, 14)
# (7261, 14)
# (7324, 14)
# (7336, 14)
# (7360, 14)
# (7384, 14)
# (7457, 14)
# (7476, 14)
# (7589, 14)
# (7590, 14)
# (7607, 14)
# (7717, 14)
# (7970, 14)
# ...

# %%
old_bank_tweets_2022.to_csv("C:/egyetem/hsdslab/twitter scraping/CSVs/new_tws_old_banks.csv")

# %%
old_bank_tweets_2022 = pd.read_csv("C:/egyetem/hsdslab/twitter scraping/CSVs/new_tws_old_banks.csv")

# %%
old_bank_tweets_2022 = old_bank_tweets_2022.drop(columns = ['Unnamed: 0'])

# %%
tweet_df.columns
# Out:
# Index(['Unnamed: 0', 'Tweet url', 'User', 'Tweet id', 'Tweet Date',
#        'Tweet Content', 'Amount of Likes', 'Amount of Replies',
#        'Amount of Retweets', 'Amount of Quotes', 'Media', 'Language',
#        'Is a Quoted Tweet', 'Mentioned Users', 'day', 'Username', 'Followers',
#        'likes_per_followers', 'replies_per_followers',
#        'retweets_per_followers', 'Media type', 'Amount of photos',
#        'Amount of videos', 'Tweet length', 'is_popular'],
#       dtype='object')

# %%
new_banks = ['BankofAmerica', 'CreditOneBank', 'SVB_Financial']

# %%
some_new_banks = pd.read_excel("C:/egyetem/hsdslab/twitter scraping/CSVs/some_more_banks.xlsx")

# %%
some_new_banks
# Out:
#                               name          Username
# 0                              FAB          @BankFAB
# 1   Bank of the Philippine Islands      @unionbankph
# 2                          Federal   @FederalBankLtd
# 3                     Commonwealth      @CommBank_ID
# 4                 Bank of Montreal              @BMO
# 5                             Absa  @AbsaSouthAfrica
# 6                              NCB           @ncb_ss
# 7                  Bank of Ireland   @centralbank_ie
# 8                Allied irish bank       @AIBIreland
# 9                          I and M         @imbankke
# 10                           Unity     @UnityBankPlc
# 11                       ING Group         @ING_news
# 12                        Heritage  @heritagebankplc
# 13                         US bank           @usbank
# 14                       Tangerine    @TangerineBank
# 15          National Bank of Kenya    @National_Bank
# 16                      BNY Melone       @BNYMellone
# ...

# %%
some_new_bank_list = []
for bank in some_new_banks['Username']:
    if bank not in set(list(banks['Bank Twitter accountja'])):
        some_new_bank_list.append(bank.replace('@', ''))

# %%
for bank in new_banks:
    if bank not in some_new_bank_list:
        some_new_bank_list.append(bank)

# %%
len(some_new_bank_list)
# Out:
# 27

# %%
some_new_bank_list[0]
# Out:
# 'BankFAB'

# %%
temp = []
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:BankFAB -filter:replies since:2012-01-01 until:2023-01-01').get_items()):
    temp.append([tweet.url, tweet.user, tweet.id, tweet.date, tweet.content, tweet.likeCount, tweet.replyCount, tweet.retweetCount, tweet.quoteCount, tweet.media, tweet.lang, tweet.retweetedTweet, tweet.quotedTweet, tweet.mentionedUsers])
    #if i == 300:
    #    break
    if i%1000 == 0:
        print(tweet.date)
    
new_bank_tweets = pd.DataFrame(temp, columns=["Tweet url", "User", "Tweet id", "Tweet Date", "Tweet Content", "Amount of Likes", "Amount of Replies", "Amount of Retweets", "Amount of Quotes", "Media", "Language", "Is a Retweet", "Is a Quoted Tweet", "Mentioned Users"])
# Out:
# 2015-02-16 13:31:08+00:00

# %%
for bank in some_new_bank_list[1:]:
    #bank = bank.replace('@', "")
    temp = []
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:'+bank +' -filter:replies since:2012-01-01 until:2023-01-01').get_items()):
        temp.append([tweet.url, tweet.user, tweet.id, tweet.date, tweet.content, tweet.likeCount, tweet.replyCount, tweet.retweetCount, tweet.quoteCount, tweet.media, tweet.lang, tweet.retweetedTweet, tweet.quotedTweet, tweet.mentionedUsers])
    
    temp_df = pd.DataFrame(temp, columns=["Tweet url", "User", "Tweet id", "Tweet Date", "Tweet Content", "Amount of Likes", "Amount of Replies", "Amount of Retweets", "Amount of Quotes", "Media", "Language", "Is a Retweet", "Is a Quoted Tweet", "Mentioned Users"])
    new_bank_tweets = pd.concat([new_bank_tweets, temp_df], ignore_index=True)
    print(new_bank_tweets.shape)
# Out:
# (3511, 14)
# (11246, 14)
# (43730, 14)
# (53355, 14)
# (53401, 14)
# (63839, 14)
# (67353, 14)
# (69428, 14)
# (75873, 14)
# (88045, 14)
# (93015, 14)
# (93015, 14)
# (94907, 14)
# (98936, 14)
# (100567, 14)
# (103902, 14)
# (104835, 14)
# (110397, 14)
# (116784, 14)
# (135685, 14)
# (139426, 14)
# (150476, 14)
# (161920, 14)
# (165686, 14)
# (166822, 14)
# (178296, 14)

# %%
new_bank_tweets.to_csv("C:/egyetem/hsdslab/twitter scraping/CSVs/new_tws_new_banks.csv")

# %% [markdown]
# Let's get the list of followers again.

# %%
temp = []
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:BNYMellon -filter:replies since:2012-01-01 until:2023-01-01').get_items()):
    temp.append([tweet.url, tweet.user, tweet.id, tweet.date, tweet.content, tweet.likeCount, tweet.replyCount, tweet.retweetCount, tweet.quoteCount, tweet.media, tweet.lang, tweet.retweetedTweet, tweet.quotedTweet, tweet.mentionedUsers])
    #if i == 300:
    #    break
    if i%1000 == 0:
        print(tweet.date)
    
BNYMellon_df = pd.DataFrame(temp, columns=["Tweet url", "User", "Tweet id", "Tweet Date", "Tweet Content", "Amount of Likes", "Amount of Replies", "Amount of Retweets", "Amount of Quotes", "Media", "Language", "Is a Retweet", "Is a Quoted Tweet", "Mentioned Users"])
# Out:
# 2022-12-25 14:01:07+00:00
# 2019-02-05 14:22:04+00:00
# 2017-06-05 12:31:59+00:00
# 2016-06-24 14:07:55+00:00
# 2015-08-13 18:27:24+00:00
# 2014-05-11 16:01:17+00:00

# %%
BNYMellon_df.to_csv("C:/egyetem/hsdslab/twitter scraping/BNYMellon_df.csv")

# %% [markdown]
# **------------------------------------------------------------------------------------------------------**

# %%
tweet_df.shape
# Out:
# (10370, 14)

# %% [markdown]
# 10 év alatt 10370 tweet, nem semmi.

# %%
#tweet_df.to_csv("C:/egyetem/hsdslab/twitter scraping/TheOfficialSBI.csv")  Ez így meglesz betölthető módon, ha még egyszer kéne futtatni

# %%
for bank in list(banks['Bank Twitter accountja'])[1:]:
    bank = bank.replace('@', "")
    temp = []
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:'+bank +' -filter:replies since:2012-01-01 until:2022-10-04').get_items()):
        temp.append([tweet.url, tweet.user, tweet.id, tweet.date, tweet.content, tweet.likeCount, tweet.replyCount, tweet.retweetCount, tweet.quoteCount, tweet.media, tweet.lang, tweet.retweetedTweet, tweet.quotedTweet, tweet.mentionedUsers])
    
    temp_df = pd.DataFrame(temp, columns=["Tweet url", "User", "Tweet id", "Tweet Date", "Tweet Content", "Amount of Likes", "Amount of Replies", "Amount of Retweets", "Amount of Quotes", "Media", "Language", "Is a Retweet", "Is a Quoted Tweet", "Mentioned Users"])
    tweet_df = pd.concat([tweet_df, temp_df], ignore_index=True)
    print(tweet_df.shape)
# Out:
# (41249, 14)
# (45234, 14)
# (50607, 14)
# (61008, 14)
# (67290, 14)
# (74525, 14)
# (88162, 14)
# (94289, 14)
# (97805, 14)
# (109365, 14)
# (113481, 14)
# (121199, 14)
# (134386, 14)
# (140350, 14)
# (146772, 14)
# (156653, 14)
# (157686, 14)
# (160385, 14)
# (162487, 14)
# (187677, 14)
# (192442, 14)
# (194929, 14)
# (204349, 14)
# (205744, 14)
# (212460, 14)
# (213003, 14)
# (219766, 14)
# (238023, 14)
# (241641, 14)
# (251107, 14)
# (256307, 14)
# (259361, 14)
# (262414, 14)
# (267968, 14)
# (269936, 14)
# (276957, 14)
# (277648, 14)
# (283149, 14)
# (295661, 14)
# (305406, 14)
# (307957, 14)
# (309608, 14)
# (312560, 14)
# (323324, 14)
# (336268, 14)
# (348745, 14)
# (358046, 14)
# (371276, 14)
# (375714, 14)
# (380190, 14)
# (396035, 14)
# (398679, 14)
# (403966, 14)
# (407276, 14)
# (415689, 14)
# (416946, 14)
# (419034, 14)
# (427302, 14)
# (429708, 14)
# (433571, 14)
# (434499, 14)
# (438389, 14)
# (440604, 14)
# (447785, 14)
# (458173, 14)
# (464489, 14)
# (468751, 14)
# ...

# %%
#tweet_df.to_csv("C:/egyetem/hsdslab/twitter scraping/bank_tweets.csv")

# %%
tweet_df = pd.read_csv("C:/egyetem/hsdslab/twitter scraping/bank_tweets.csv", header = 0)

# %%
tweet_df.shape
# Out:
# (642684, 15)

# %%
tweet_df.head()
# Out:
#    Unnamed: 0                                          Tweet url  \
# 0           0  https://twitter.com/TheOfficialSBI/status/1576...
# 1           1  https://twitter.com/TheOfficialSBI/status/1576...
# 2           2  https://twitter.com/TheOfficialSBI/status/1576...
# 3           3  https://twitter.com/TheOfficialSBI/status/1576...
# 4           4  https://twitter.com/TheOfficialSBI/status/1576...
#
#                                  User             Tweet id  \
# 0  https://twitter.com/TheOfficialSBI  1576926803154739200
# 1  https://twitter.com/TheOfficialSBI  1576914211107614720
# 2  https://twitter.com/TheOfficialSBI  1576881046053785600
# 3  https://twitter.com/TheOfficialSBI  1576824179327791105
# 4  https://twitter.com/TheOfficialSBI  1576796466340802560
#
#                   Tweet Date  \
# 0  2022-10-03 13:27:02+00:00
# 1  2022-10-03 12:37:00+00:00
# 2  2022-10-03 10:25:13+00:00
# 3  2022-10-03 06:39:14+00:00
# 4  2022-10-03 04:49:07+00:00
#
# ...

# %%
tweet_df.Media
# Out:
# 0         [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# 1         [Photo(previewUrl='https://pbs.twimg.com/media...
# 2         [Photo(previewUrl='https://pbs.twimg.com/media...
# 3         [Photo(previewUrl='https://pbs.twimg.com/media...
# 4         [Photo(previewUrl='https://pbs.twimg.com/media...
#                                 ...
# 642679    [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# 642680    [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# 642681    [Video(thumbnailUrl='https://pbs.twimg.com/ext...
# 642682    [Photo(previewUrl='https://pbs.twimg.com/media...
# 642683    [Photo(previewUrl='https://pbs.twimg.com/media...
# Name: Media, Length: 642684, dtype: object

# %%
list(tweet_df.Media)
# Out:
# ["[Video(thumbnailUrl='https://pbs.twimg.com/ext_tw_video_thumb/1576926061001986048/pu/img/POkcSjouJLbjL9sa.jpg', variants=[VideoVariant(contentType='video/mp4', url='https://video.twimg.com/ext_tw_video/1576926061001986048/pu/vid/320x320/IAH1uF4KQRKgaICD.mp4?tag=12', bitrate=432000), VideoVariant(contentType='video/mp4', url='https://video.twimg.com/ext_tw_video/1576926061001986048/pu/vid/540x540/vmEkfD3-pDjDryso.mp4?tag=12', bitrate=832000), VideoVariant(contentType='application/x-mpegURL', url='https://video.twimg.com/ext_tw_video/1576926061001986048/pu/pl/Uzzji47odnPBM51U.m3u8?tag=12&container=fmp4', bitrate=None), VideoVariant(contentType='video/mp4', url='https://video.twimg.com/ext_tw_video/1576926061001986048/pu/vid/720x720/g2AK15cEe50fjeWd.mp4?tag=12', bitrate=1280000)], duration=55.766, views=3067)]",
#  "[Photo(previewUrl='https://pbs.twimg.com/media/FeJTGIGVsAAxFEK?format=jpg&name=small', fullUrl='https://pbs.twimg.com/media/FeJTGIGVsAAxFEK?format=jpg&name=large')]",
# ...

# %%
tweet_df.Media.isna().sum()
# Out:
# 319933

# %%
list(tweet_df.Media)[0]
# Out:
# "[Video(thumbnailUrl='https://pbs.twimg.com/ext_tw_video_thumb/1576926061001986048/pu/img/POkcSjouJLbjL9sa.jpg', variants=[VideoVariant(contentType='video/mp4', url='https://video.twimg.com/ext_tw_video/1576926061001986048/pu/vid/320x320/IAH1uF4KQRKgaICD.mp4?tag=12', bitrate=432000), VideoVariant(contentType='video/mp4', url='https://video.twimg.com/ext_tw_video/1576926061001986048/pu/vid/540x540/vmEkfD3-pDjDryso.mp4?tag=12', bitrate=832000), VideoVariant(contentType='application/x-mpegURL', url='https://video.twimg.com/ext_tw_video/1576926061001986048/pu/pl/Uzzji47odnPBM51U.m3u8?tag=12&container=fmp4', bitrate=None), VideoVariant(contentType='video/mp4', url='https://video.twimg.com/ext_tw_video/1576926061001986048/pu/vid/720x720/g2AK15cEe50fjeWd.mp4?tag=12', bitrate=1280000)], duration=55.766, views=3067)]"

# %%
user_list = []

# %%
users_name = []
for bank in list(banks['Bank Twitter accountja']):
    users_name.append(bank.replace('@', ""))

#.replace('@', "")

# %%
len(users_name)
# Out:
# 103

# %%
users_name = [bank for bank in users_name if bank not in ['RBI_Presse', 'Bank_Security']]

# %%
users_name += some_new_bank_list

# %%
len(users_name)
# Out:
# 130

# %%
users_name = [w.replace('BNYMellone', 'BNYMellon') for w in users_name]

# %%
users_name[0]
# Out:
# 'TheOfficialSBI'

# %%
temp = []
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:TheOfficialSBI -filter:replies since:2012-01-01 until:2022-10-04').get_items()):
    temp.append([tweet.url, tweet.user, tweet.user.username, tweet.user.followersCount])
    if i == 0:
        break
    if i%1000 == 0:
        print(tweet.date)
    
test_df = pd.DataFrame(temp, columns=["Tweet url", "User", "tweet.user.username", "tweet.user.followersCount"])

# %%
test_df
# Out:
#                                            Tweet url  \
# 0  https://twitter.com/TheOfficialSBI/status/1576...
#
#                                  User tweet.user.username  \
# 0  https://twitter.com/TheOfficialSBI      TheOfficialSBI
#
#    tweet.user.followersCount
# 0                    4620695

# %%
for bank in users_name[1:]:
    #bank = bank.replace('@', "")
    temp = []
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:'+bank +' -filter:replies since:2012-01-01 until:2022-10-04').get_items()):
        temp.append([tweet.url, tweet.user, tweet.user.username, tweet.user.followersCount])
        if i == 0:
            break
    
    temp_df = pd.DataFrame(temp, columns=["Tweet url", "User", "tweet.user.username", "tweet.user.followersCount"])
    test_df = pd.concat([test_df, temp_df], ignore_index=True)
    print(test_df.shape)
# Out:
# (2, 4)
# (3, 4)
# (4, 4)
# (5, 4)
# (6, 4)
# (7, 4)
# (8, 4)
# (9, 4)
# (10, 4)
# (11, 4)
# (12, 4)
# (13, 4)
# (14, 4)
# (15, 4)
# (16, 4)
# (17, 4)
# (18, 4)
# (19, 4)
# (20, 4)
# (21, 4)
# (22, 4)
# (23, 4)
# (24, 4)
# (25, 4)
# (26, 4)
# (27, 4)
# (28, 4)
# (29, 4)
# (30, 4)
# (31, 4)
# (32, 4)
# (33, 4)
# (34, 4)
# (35, 4)
# (36, 4)
# (37, 4)
# (38, 4)
# (39, 4)
# (40, 4)
# (41, 4)
# (42, 4)
# (43, 4)
# (44, 4)
# (45, 4)
# (46, 4)
# (47, 4)
# (48, 4)
# (49, 4)
# (50, 4)
# (51, 4)
# (52, 4)
# (53, 4)
# (54, 4)
# (55, 4)
# (56, 4)
# (57, 4)
# (58, 4)
# (59, 4)
# (60, 4)
# (61, 4)
# (62, 4)
# (63, 4)
# (64, 4)
# (65, 4)
# (66, 4)
# (67, 4)
# (68, 4)
# (69, 4)
# (70, 4)
# (71, 4)
# (72, 4)
# (73, 4)
# (74, 4)
# (75, 4)
# (76, 4)
# (77, 4)
# (78, 4)
# (79, 4)
# (80, 4)
# (81, 4)
# (82, 4)
# (83, 4)
# (84, 4)
# (85, 4)
# (86, 4)
# (87, 4)
# (88, 4)
# (89, 4)
# (90, 4)
# (91, 4)
# (92, 4)
# (93, 4)
# (94, 4)
# (95, 4)
# (96, 4)
# (97, 4)
# (98, 4)
# (99, 4)
# (100, 4)
# (101, 4)
# ...

# %%
test_df
# Out:
#                                              Tweet url  \
# 0    https://twitter.com/TheOfficialSBI/status/1576...
# 1    https://twitter.com/ICICIBank/status/157694265...
# 2    https://twitter.com/KotakBankLtd/status/157641...
# 3    https://twitter.com/AxisBank/status/1576935640...
# 4    https://twitter.com/YESBANK/status/15769369952...
# ..                                                 ...
# 125  https://twitter.com/KeEquityBank/status/157688...
# 126  https://twitter.com/gtbank/status/157686436298...
# 127  https://twitter.com/BankofAmerica/status/15769...
# 128  https://twitter.com/CreditOneBank/status/15765...
# 129  https://twitter.com/SVB_Financial/status/15769...
#
#                                    User tweet.user.username  \
# 0    https://twitter.com/TheOfficialSBI      TheOfficialSBI
# 1         https://twitter.com/ICICIBank           ICICIBank
# 2      https://twitter.com/KotakBankLtd        KotakBankLtd
# ...

# %%
len(users_name)
# Out:
# 110

# %%
len(user_list)
# Out:
# 109

# %%
test_df.to_csv("C:/egyetem/hsdslab/twitter scraping/CSVs/followers.csv")

# %%
for bank in users_name:
    if bank not in list(test_df['tweet.user.username']):
        print(bank)
        break
# Out:
# BNYMellone

# %%
test_df['tweet.user.followersCount'].min()
# Out:
# 1163

# %%
test_df.query('`tweet.user.followersCount` == 1163')
# Out:
#                                              Tweet url  \
# 103  https://twitter.com/fvbankus/status/1575485718...
#
#                              User tweet.user.username  \
# 103  https://twitter.com/fvbankus            fvbankus
#
#     tweet.user.followersCount
# 103                      1163
